# %%
# !pip install scikit-image pillow -q # https://scikit-image.org/

# %%
import urllib.request
import numpy as np
import matplotlib.pyplot as plt
import skimage as ski
from PIL import Image, ImageFont, ImageDraw
from PIL import ImageChops
import PIL.ImageStat as stat
from skimage import io
from skimage import color, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage
import matplotlib.image as mpimg

# %%
from skimage.exposure import histogram
coins = ski.data.coins()
hist, hist_centers = ski.exposure.histogram(coins)

# %%
plt.imshow(coins, cmap='gray')

# %%
coffee = ski.data.coffee()
plt.imshow(coffee)

# %%
url = "https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/81/11/huggingface-logo-venture.component.crop-2by1-xl.ts=1747140549427.png/content/adobe-cms/us/en/think/topics/hugging-face/jcr:content/root/leadspace_container/leadspace_article"

# %%
archivo = "leadspace_article.png"
urllib.request.urlretrieve(url, archivo)

# %%
im = Image.open(archivo)
plt.imshow(im)
plt.axis("off")
